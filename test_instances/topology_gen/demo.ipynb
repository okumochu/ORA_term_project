# %%
from gen_diff_topo import transform_to_FJSSP

# %%
input_files = []
output_path = []

for i in range(len(input_files)):
    for flex in range(2, 5):
        # closed
        transform_to_FJSSP(input_path=input_files[i], flex=flex, output_path=output_path[i], closed=True)
        # linked
        transform_to_FJSSP(input_path=input_files[i], flex=flex, output_path=output_path[i], closed=False)

# %%
transform_to_FJSSP(input_path="./tai_j10_m10_1.data", flex=3, output_path="./tai_j10_m10_1_closed.data", closed=False)
